# %% [markdown]
# # Data Visualization World Happiness Report

# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %%
# Import necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the dataset
df=pd.read_csv("happiness_score_dataset.csv")

# %%
# print the first 10 rows of "happiness_score_dataset"
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
# find the least countries
df.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %%
# Check the column names
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Unnamed: 12'],
#       dtype='object')

# %%
# Check the total number of rows & columns
df.shape
# Out:
# (158, 13)

# %%
# Check the data-type
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Unnamed: 12                      float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# Get some Statistics
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
# Checking Null Values
df.isnull().sum()
# Out:
# Country                            0
# Region                             0
# Happiness Rank                     0
# Happiness Score                    0
# Standard Error                     0
# Economy (GDP per Capita)           0
# Family                             0
# Health (Life Expectancy)           0
# Freedom                            0
# Trust (Government Corruption)      0
# Generosity                         0
# Dystopia Residual                  0
# Unnamed: 12                      158
# dtype: int64

# %%
#Number of countries in our dataset
len(df['Country'].unique())
# Out:
# 158

# %%
#Number of regions
len(df['Region'].unique())
# Out:
# 10

# %% [markdown]
# Since we have 10 regions and 158 countries, we can subset our dataset to regions and look at the distributions.

# %%
# Let's check the correlation between variables
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
# Unnamed: 12                               NaN              NaN
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# ...

# %%
df1= df.sort_values(by=["Happiness Score"], ascending=False)
df1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df1.drop(["Unnamed: 12"],axis=1,inplace=True)

# %%
df1.reset_index(inplace=True,drop=True)
df1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df1.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
#World Happiness Score Freedom - 2015
plt.figure(figsize=(18,5))
sns.set(style='whitegrid')
ax=sns.barplot(x=df1['Region'].value_counts().index,y=df1['Region'].value_counts().values,palette="Blues_d")
plt.legend(loc=8)
plt.xlabel('Region')
plt.xticks(rotation=75)
plt.ylabel('Frequency')
plt.title('Show of region Bar Plot')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
f,ax=plt.subplots(figsize=(9,10))
sns.barplot(x=df1['Country'].value_counts().values,y=df1['Country'].value_counts().index,alpha=0.5,color='red',label='Country')
sns.barplot(x=df1['Region'].value_counts().values,y=df1['Region'].value_counts().index,color='blue',alpha=0.7,label='Region')
ax.legend(loc='upper right',frameon=True)
ax.set(xlabel='Country , Region',ylabel='Groups',title="Country vs Region ")
plt.show()

# %%
labels=df1['Region'].value_counts().index
colors=['blue','red','yellow','green','brown']
explode=[0.3,0.3,0.2,0.1,0,0,0,0,0,0]
values=df1['Region'].value_counts().values

#visualization
plt.figure(figsize=(7,7))
plt.pie(values,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title('Region According Analysis',color='black',fontsize=10)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lmplot(x='Happiness Score',y='Economy (GDP per Capita)',data=df1)
plt.xlabel('Happiness Score')
plt.ylabel('Economy (GDP per Capita)')
plt.title('Happiness Score vs Economy (GDP per Capita)')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lmplot(x='Happiness Score',y='Health (Life Expectancy)',data=df1)
plt.xlabel('Happiness Score')
plt.ylabel('Halth (Life Expectancy)	')
plt.title('Happiness Score vs Health (Life Expectancy)')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lmplot(x='Happiness Score',y='Trust (Government Corruption)',data=df1)
plt.xlabel('Happiness Score')
plt.ylabel('Trust (Government Corruption)')
plt.title('Happiness Score vs Trust (Government Corruption)')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lmplot(x='Happiness Score',y='Freedom',data=df1)
plt.xlabel('Happiness Score')
plt.ylabel('Freedom')
plt.title('Happiness Score vs Freedom')
plt.show()

# %%
plt.figure(figsize=(18,7))
sns.lmplot(x='Economy (GDP per Capita)',y='Health (Life Expectancy)',hue='Region',data=df1)
plt.xlabel('Happiness Score')
plt.ylabel('Trust (Government Corruption)')
plt.title('Happiness Score vs Trust (Government Corruption)')
plt.show()

# %%
sns.kdeplot(df1['Happiness Score'])
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Happiness Score Kde Plot System Analysis')
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.kdeplot(df1['Health (Life Expectancy)'],shade=True,color='r')
sns.kdeplot(df1['Economy (GDP per Capita)'],shade=True,color='g')
sns.kdeplot(df1['Freedom'],shade=True,color='black')
sns.kdeplot(df1['Family'],shade=True,color='orange')
sns.kdeplot(df1['Generosity'],shade=True,color='yellow')
sns.kdeplot(df1['Dystopia Residual'],shade=True,color='brown')
sns.kdeplot(df1['Trust (Government Corruption)'],shade=True,color='b')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Health (Life Expectancy), Economy (GDP per Capita), Freedom, Family, Generosity,Dystopia Residual, Trust Kde Plot System Analysis')
plt.show()

# %%
sns.violinplot(df1['Happiness Score'])
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.title('Violin Happiness Score Show')
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.violinplot(x=df1['Region'],y=df1['Economy (GDP per Capita)'])
plt.xticks(rotation=75)
plt.show()

# %%
sns.heatmap(df1.corr())
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.heatmap(df1.corr(),annot=True,fmt=".0%")
plt.show()

# %%
# Compute the correlation matrix
corr = df1.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.set(style='whitegrid')
sns.boxplot(df1['Happiness Score'])
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.boxplot(x=df1['Region'],y=df1['Happiness Score'])
plt.xticks(rotation=75)
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.boxenplot(x="Region", y="Health (Life Expectancy)",
              color="b",
              scale="linear", data=df1)
plt.xticks(rotation=75)
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.boxplot(x=df1['Region'],y=df1['Happiness Score'])
plt.xticks(rotation=75)
sns.swarmplot(x=df1['Region'],y=df1['Happiness Score'],color=".25")
plt.xticks(rotation=75)
plt.show()

# %%
sns.set(style='whitegrid')
sns.swarmplot(x=df1['Happiness Score'])
plt.show()

# %%
sns.set(style="whitegrid")

sns.swarmplot(y=df1["Happiness Score"],color='red')
sns.swarmplot(y=df1["Dystopia Residual"],color='blue')
sns.swarmplot(y=df1["Economy (GDP per Capita)"],color='yellow')
sns.swarmplot(y=df1["Trust (Government Corruption)"],color='purple')
sns.swarmplot(y=df1["Health (Life Expectancy)"],color='green')

plt.title('Happiness Score & Dystopia Residual & Economy (GDP per Capita)  & Trust (Government Corruption) & Health (Life Expectancy)')
plt.show()

# %%
sns.swarmplot(x=df1['Economy (GDP per Capita)'],y=df1['Health (Life Expectancy)'])
plt.show()

# %%
sns.pairplot(df1)
plt.show()

# %%
sns.pairplot(df1,diag_kind='kde')
plt.show()

# %%
sns.countplot(df1['Region'])
plt.xticks(rotation=75)
plt.show()

# %%
ax = sns.distplot(df1['Family'], color="y")
plt.show()

# %%
df1.groupby('Region')[['Happiness Score','Economy (GDP per Capita)']].mean()
# Out:
#                                  Happiness Score  Economy (GDP per Capita)
# Region
# Australia and New Zealand               7.285000                  1.291880
# Central and Eastern Europe              5.332931                  0.942438
# Eastern Asia                            5.626167                  1.151780
# Latin America and Caribbean             6.144682                  0.876815
# Middle East and Northern Africa         5.406900                  1.066973
# North America                           7.273000                  1.360400
# Southeastern Asia                       5.317444                  0.789054
# Southern Asia                           4.580857                  0.560486
# Sub-Saharan Africa                      4.202800                  0.380473
# Western Europe                          6.689619                  1.298596

# %%
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df1.Country[:20])
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200, background_color="black").generate(text)
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df1 = df1.iloc[:3, :]
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go

trace1 = go.Bar(
                x = df1.Country,
                y = df1['Economy (GDP per Capita)'],
                name = "Economy (GDP per Capita)",
                marker = dict(color = 'rgba(125, 25, 200, 0.8)',
                             line = dict(color = 'rgb(0,0,0)', width = 1.5))
                )
trace2 = go.Bar(
                x = df1.Country,
                y = df1.Family,
                name = "Family",
                marker = dict(color = 'rgba(25, 25, 25, 0.8)',
                             line = dict(color = 'rgb(0,0,0)', width = 1.5))
                )
trace3 = go.Bar(
                x = df1.Country,
                y = df1['Health (Life Expectancy)'],
                name = "Health (Life Expectancy)",
                marker = dict(color = 'rgba(190, 200, 100, 0.8)',
                             line = dict(color = 'rgb(0,0,0)', width = 1.5))
                )
trace4 = go.Bar(
                x = df1.Country,
                y = df1['Trust (Government Corruption)'],
                name = "Trust (Government Corruption)",
                marker = dict(color = 'rgba(50, 150, 50, 0.8)',
                             line = dict(color = 'rgb(0,0,0)', width = 1.5))
                )
trace5 = go.Bar(
                x = df1.Country,
                y = df1.Generosity,
                name = "Generosity",
                marker = dict(color = 'rgba(255, 70, 12, 0.8)',
                             line = dict(color = 'rgb(0,0,0)', width = 1.5))
                )
trace6 = go.Bar(
                x = df1.Country,
                y = df1.Freedom,
                name = "Freedom",
                marker = dict(color = 'rgba(255, 25, 55, 0.8)',
                             line = dict(color = 'rgb(0,0,0)', width = 1.5))
                )
data = [trace1, trace2, trace3, trace4, trace5, trace6]
layout = go.Layout(barmode = 'group', title = 'Top 3 Countries  According to the Different Parameters')
fig = go.Figure(data = data, layout = layout)
iplot(fig)
df1 = df1.iloc[:3, :]
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
df1 = df1.iloc[:3, :]

trace1 = {
  'x': df1.Country,
  'y': df1['Economy (GDP per Capita)'],
  'name': 'Economy (GDP per Capita)',
  'type': 'bar'
};
trace2 = {
  'x': df1.Country,
  'y': df1.Family,
  'name': 'Family',
  'type': 'bar'
};
trace3 = {
  'x': df1.Country,
  'y': df1['Health (Life Expectancy)'],
  'name': 'Health (Life Expectancy)',
  'type': 'bar'
};
trace4 = {
  'x': df1.Country,
  'y': df1['Trust (Government Corruption)'],
  'name': 'Trust (Government Corruption)',
  'type': 'bar'
};
trace5 = {
  'x': df1.Country,
  'y': df1.Generosity,
  'name': 'Generosity',
  'type': 'bar'
};
trace6 = {
  'x': df1.Country,
  'y': df1.Freedom,
  'name': 'Freedom',
  'type': 'bar'
};
data = [trace1, trace2, trace3, trace4, trace5, trace6];
layout = {
  'xaxis': {'title': 'Top 3 Countries'},
  'barmode': 'relative',
  'title': 'Top 3 Countries  According to the Different Parameters'
};
fig = go.Figure(data = data, layout = layout)
iplot(fig)
df
# Out:
# <div>                            <div id="379bc523-e7f3-4f1b-a53c-66ead4db43c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("379bc523-e7f3-4f1b-a53c-66ead4db43c0")) {                    Plotly.newPlot(                        "379bc523-e7f3-4f1b-a53c-66ead4db43c0",                        [{"name": "Economy (GDP per Capita)", "type": "bar", "x": ["Switzerland", "Iceland", "Denmark"], "y": [1.3965100000000001, 1.3023200000000001, 1.32548]}, {"name": "Family", "type": "bar", "x": ["Switzerland", "Iceland", "Denmark"], "y": [1.34951, 1.4022299999999999, 1.36058]}, {"name": "Health (Life Expectancy)", "type": "bar", "x": ["Switzerland", "Iceland", "Denmark"], "y": [0.9414299999999999, 0.94784, 0.87464]}, {"name": "Trust (Government Corruption)", "type"
# ...

# %%
data = dict(type = 'choropleth', 
           locations = df1['Country'],
           locationmode = 'country names',
           z = df1['Happiness Rank'],
           colorbar = {'title':'Happiness Score'})
layout = dict(title = 'Global Happiness Ranking', 
             geo = dict(showframe = False, 
                       projection = {'type': 'natural earth'}))
choromap = go.Figure(data = [data], layout = layout)
iplot(choromap)
# Out:
# <div>                            <div id="d6b4191e-3af7-4ed5-8756-62a55abe40d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6b4191e-3af7-4ed5-8756-62a55abe40d7")) {                    Plotly.newPlot(                        "d6b4191e-3af7-4ed5-8756-62a55abe40d7",                        [{"colorbar": {"title": {"text": "Happiness Score"}}, "locationmode": "country names", "locations": ["Switzerland", "Iceland", "Denmark"], "type": "choropleth", "z": [1, 2, 3]}],                        {"geo": {"projection": {"type": "natural earth"}, "showframe": false}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {
# ...
